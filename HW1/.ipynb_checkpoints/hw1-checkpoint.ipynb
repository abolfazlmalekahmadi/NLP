# %%
# !pip install hazm
# Out:
# Collecting hazm
#   Downloading hazm-0.7.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.7/316.7 kB 852.4 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Collecting libwapiti>=0.2.1
#   Downloading libwapiti-0.2.1.tar.gz (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 573.9 kB/s eta 0:00:001m587.0 kB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /Users/abolfazl/opt/anaconda3/lib/python3.9/site-packages (from nltk==3.3->hazm) (1.16.0)
# Building wheels for collected packages: nltk, libwapiti
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394471 sha256=7629dbc85ea41aa75407919f47ecc81fadfdc121a89c3852372b51987949bad7
#   Stored in directory: /Users/abolfazl/Library/Caches/pip/wheels/ac/62/f6/88933dadcd64a1614894614aa68cf57c4b8e5256acb650b1f1
#   Building wheel for libwapiti (setup.py) ... done
#   Created wheel for libwapiti: filename=libwapiti-0.2.1-cp39-cp39-macosx_10_9_x86_64.whl size=57228 sha256=d20867596774d42c1eb783c0856daec9f18d32f2d83c148f3ac3d9052fa7732b
#   Stored in directory: /Users/abolfazl/Library/Caches/pip/wheels/8e/ff/82/9326b96f96f47472e02c453697b225813e4650c0ed4df2cd49
# Successfully built nltk libwapiti
# Installing collected packages: nltk, libwapiti, hazm
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed hazm-0.7.0 libwapiti-0.2.1 nltk-3.3

# %%
from __future__ import unicode_literals
import pandas as pd
import random 
import numpy as np
import nltk
import pandas as pd
import codecs
import tqdm
from hazm import *

# %%
normalizer = Normalizer()

# %%
review_address = "drive/MyDrive/Projects/NLP/HW1/reviews.csv"
stop_words_address = "drive/MyDrive/Projects/NLP/HW1/stopwords.txt"
pos_tagger_model_address = "drive/MyDrive/Projects/NLP/HW1/postagger.model"

# %%
review_df = pd.read_csv(review_address)

# %%
review_list = []
for index, row in review_df.iterrows():
  review_list.append(row["text"])
print(f"Number of reviews = {len(review_list)}")
# Out:
# Number of reviews = 200

# %%
review_list_sent_tokenized = []
for review in review_list:
  review_list_sent_tokenized.append(sent_tokenize(review))
print(f"Number of sentences in the first review = {len(review_list_sent_tokenized[0])}")
print(f"First sentence of the first review:\n{review_list_sent_tokenized[0][0]}")
# Out:
# Number of sentences in the first review = 41
# First sentence of the first review:
# فیلم مخلوقات خدا، درامی باحوصله و آرام‌سوز است که تلاش می‌کند سوژه‌ای آشنا را از زاویه‌ای تازه ببیند.

# %%
random_review_indices = random.sample(range(len(review_list)), 3)
print(random_review_indices)
# Out:
# [50, 188, 153]

# %%
normalized_review_list_sent_tokenized = []
for review in review_list_sent_tokenized:
  sentence_list = []
  for sentence in review:
    sentence_list.append(normalizer.normalize(sentence))
  normalized_review_list_sent_tokenized.append(sentence_list)

# %%
for random_review_index in random_review_indices:
  print(100 * "-")
  for i in range(4):
    print(normalized_review_list_sent_tokenized[random_review_index][i])
# Out:
# ----------------------------------------------------------------------------------------------------
# از آثار ماندگار لوییس بونوئل تا پدرو آلمادوار.
# در این مقاله به معرفی ۴۰ فیلم جذاب اسپانیایی زبان می‌پردازیم.
# همراه زومجی باشید. در سال‌های اخیر فیلم‌های اسپانیایی در سرتاسر جهان شهرت بسیار پیدا کرده‌اند.
# سینمای اسپانیا بسیار غنی است و فرقی نمی‌کند طرفدار چه ژانری باشید، ده‌ها فیلم خوب اسپانیایی وجود دارد که دیدن آن‌ها به همه توصیه می‌شود.
# ----------------------------------------------------------------------------------------------------
# فیلم بی مادر به کارگردانی مرتضی فاطمی از آثار حاضر در جشنواره فجر امسال است.
# اثری که در پس پیرنگ آشفته‌ی خود به شخصیت‌هایی فاقد شناسنامه می‌رسد و در غیرداراماتیک‌ترین شکل ممکن روایت را پیش می‌برد. فیلم بی مادر به اولین تجربه‌ی کارگردانی مرتضی فاطمی و تهیه‌کنندگی علی اوجی دنباله‌ی آثار بی‌فیلمنامه‌ی این دوره از جشنواره‌ی فیلم فجر است.
# اثری که علاوه‌بر فیلمنامه‌ی ناقص خود اجرای خوبی هم ندارد و در بازیگری لنگ می‌زند.
# یک نمایش تکراری که رونوشتی از فیلم‌ها و سریال‌هایی است که سرکی به قشر فلک‌زده‌ی جامعه می‌زند و آن‌ها را در تقاطع با طبقه‌ی مرفه قرار می‌دهد.
# ----------------------------------------------------------------------------------------------------
# فیلم داستان وست ساید (west side story) اسپیلبرگ چقدر توانسته مثل یک بازسازی باشد؟
# آن هم از فیلمی پرافتخار و پرانرژی.
# با نقد این فیلم همراه زومجی باشید. ایده بازسازی فیلم‌های کلاسیک و پرطرفدار، یکی از چالش‌برانگیزترین و در عین حال هیجان‌انگیزترین سیاست‌های فیلمسازی هالیوود است.
# به عقیده‌ی شرکت‌های فیلم‌سازی، آثاری که در گذشته مورد قبول مخاطبان بوده‌اند، این روزها به‌واسطه‌ی برانگیختن حس نوستالژی در ذهن تماشاگر بار دیگر نیز می‌توانند تضمینی برای گیشه باشند، آنهم در شرایطی که استودیوهای فیلم، پیشرفت‌های فوق‌العاده چشم‌گیری در زمینه‌ی تجهیزات فنی و بصری به‌خود دیده‌اند و می‌توانند ایرادات فیلم اصلی را نیز برطرف کنند. این بازسازی‌ها، تجربه‌ای وسوسه‌کننده برای دوستداران سینماست، چراکه آن‌‌ها قرار است قصه‌ای زرق‌وبرق‌دار را با رنگ و لعابی جدید ببینند.

# %%
! pip install dadmatools

# %%
from dadmatools.models.normalizer import Normalizer

dadma_normalizer = Normalizer(
    full_cleaning=True,
    unify_chars=True,
    refine_punc_spacing=True,
    remove_extra_space=True,
    remove_puncs=False,
    remove_html=False,
    remove_stop_word=False,
    replace_email_with="",
    replace_number_with="",
    replace_url_with="",
    replace_mobile_number_with=None,
    replace_emoji_with=None,
    replace_home_number_with=None,
)

# %%
dadma_normalized_review_list_sent_tokenized = []
for review in review_list_sent_tokenized:
  sentence_list = []
  for sentence in review:
    sentence_list.append(normalizer.normalize(sentence))
  dadma_normalized_review_list_sent_tokenized.append(sentence_list)

# %%
for random_review_index in random_review_indices:
  print(100 * "-")
  for i in range(4):
    print(dadma_normalized_review_list_sent_tokenized[random_review_index][i])
# Out:
# ----------------------------------------------------------------------------------------------------
# از آثار ماندگار لوییس بونوئل تا پدرو آلمادوار.
# در این مقاله به معرفی ۴۰ فیلم جذاب اسپانیایی زبان می‌پردازیم.
# همراه زومجی باشید. در سال‌های اخیر فیلم‌های اسپانیایی در سرتاسر جهان شهرت بسیار پیدا کرده‌اند.
# سینمای اسپانیا بسیار غنی است و فرقی نمی‌کند طرفدار چه ژانری باشید، ده‌ها فیلم خوب اسپانیایی وجود دارد که دیدن آن‌ها به همه توصیه می‌شود.
# ----------------------------------------------------------------------------------------------------
# فیلم بی مادر به کارگردانی مرتضی فاطمی از آثار حاضر در جشنواره فجر امسال است.
# اثری که در پس پیرنگ آشفته‌ی خود به شخصیت‌هایی فاقد شناسنامه می‌رسد و در غیرداراماتیک‌ترین شکل ممکن روایت را پیش می‌برد. فیلم بی مادر به اولین تجربه‌ی کارگردانی مرتضی فاطمی و تهیه‌کنندگی علی اوجی دنباله‌ی آثار بی‌فیلمنامه‌ی این دوره از جشنواره‌ی فیلم فجر است.
# اثری که علاوه‌بر فیلمنامه‌ی ناقص خود اجرای خوبی هم ندارد و در بازیگری لنگ می‌زند.
# یک نمایش تکراری که رونوشتی از فیلم‌ها و سریال‌هایی است که سرکی به قشر فلک‌زده‌ی جامعه می‌زند و آن‌ها را در تقاطع با طبقه‌ی مرفه قرار می‌دهد.
# ----------------------------------------------------------------------------------------------------
# فیلم داستان وست ساید (west side story) اسپیلبرگ چقدر توانسته مثل یک بازسازی باشد؟
# آن هم از فیلمی پرافتخار و پرانرژی.
# با نقد این فیلم همراه زومجی باشید. ایده بازسازی فیلم‌های کلاسیک و پرطرفدار، یکی از چالش‌برانگیزترین و در عین حال هیجان‌انگیزترین سیاست‌های فیلمسازی هالیوود است.
# به عقیده‌ی شرکت‌های فیلم‌سازی، آثاری که در گذشته مورد قبول مخاطبان بوده‌اند، این روزها به‌واسطه‌ی برانگیختن حس نوستالژی در ذهن تماشاگر بار دیگر نیز می‌توانند تضمینی برای گیشه باشند، آنهم در شرایطی که استودیوهای فیلم، پیشرفت‌های فوق‌العاده چشم‌گیری در زمینه‌ی تجهیزات فنی و بصری به‌خود دیده‌اند و می‌توانند ایرادات فیلم اصلی را نیز برطرف کنند. این بازسازی‌ها، تجربه‌ای وسوسه‌کننده برای دوستداران سینماست، چراکه آن‌‌ها قرار است قصه‌ای زرق‌وبرق‌دار را با رنگ و لعابی جدید ببینند.

# %%
review_list_word_tokenized = []
for review in normalized_review_list_sent_tokenized:
  word_list = []
  for sentence in review:
    word_list.append(word_tokenize(sentence))
  review_list_word_tokenized.append(word_list)
print(f"Words of the first sentence of the first article:\n{review_list_word_tokenized[0][0]}")
# Out:
# Words of the first sentence of the first article:
# ['فیلم', 'مخلوقات', 'خدا', '،', 'درامی', 'باحوصله', 'و', 'آرام\u200cسوز', 'است', 'که', 'تلاش', 'می\u200cکند', 'سوژه\u200cای', 'آشنا', 'را', 'از', 'زاویه\u200cای', 'تازه', 'ببیند', '.']

# %%
from nltk import FreqDist
import itertools
import pandas as pd
all_tokens = list(itertools.chain(*itertools.chain(*review_list_word_tokenized)))
dataframe = {}
dataframe["all"] = FreqDist(eval(F"all_tokens")).most_common(50)
freq_analysis = pd.DataFrame(dataframe)

# %%
freq_analysis
# Out:
#                all
# 0       (و, 18063)
# 1       (., 16517)
# 2       (،, 16013)
# 3      (که, 14737)
# 4      (به, 14032)
# 5      (در, 13595)
# 6      (از, 13243)
# 7      (را, 10663)
# 8      (این, 7930)
# 9       (با, 6853)
# 10     (است, 6837)
# 11    (برای, 4505)
# 12      (او, 4484)
# 13    (فیلم, 4199)
# 14      (یک, 3985)
# 15  (می‌کند, 3746)
# 16      (آن, 3074)
# 17     (اما, 2956)
# 18      (هم, 2462)
# 19  (می‌شود, 2393)
# 20      (تا, 2152)
# 21       (:, 2114)
# 22     (خود, 1883)
# 23    (دارد, 1864)
# 24       ((, 1757)
# 25       (), 1756)
# 26   (آن‌ها, 1679)
# 27   (سریال, 1627)
# 28     (کند, 1569)
# 29   (اینکه, 1484)
# 30       (؛, 1474)
# 31    (کردن, 1360)
# 32       («, 1286)
# 33       (», 1283)
# 34  (می‌دهد, 1191)
# 35  (داستان, 1191)
# 36     (روی, 1124)
# 37      (یا, 1115)
# 38    (خودش, 1074)
# 39  (اپیزود, 1022)
# 40    (نیست, 1019)
# 41    (دیگر, 1017)
# 42    (جیمی, 1011)
# 43     (قرار, 997)
# 44      (یکی, 937)
# 45    (شخصیت, 924)
# 46      (کیم, 906)
# 47      (شدن, 897)
# 48       (دو, 895)
# 49      (فصل, 891)

# %%
print ('%-16s' % 'Number of words', '%-16s' % len(all_tokens))
print ('%-16s' % 'Number of unique words', '%-16s' % len(set(all_tokens)))
avg=np.sum([len(word) for word in all_tokens])/len(all_tokens)
print ('%-16s' % 'Average word length', '%-16s' % avg)
print ('%-16s' % 'Longest word', '%-16s' % all_tokens[np.argmax([len(word) for word in all_tokens])])
# Out:
# Number of words  518289
# Number of unique words 31597
# Average word length 4.116608687431143
# Longest word     واقع‌گرایانه/فوتورییلستیک

# %%
stopwords = [normalizer.normalize(x.strip()) for x in codecs.open(stop_words_address,'r','utf-8').readlines()]
print(stopwords[:5])
# Out:
# ['و', 'ز', 'در', 'به', 'از']

# %%
all_tokens_nonstop = [t for t in tqdm.tqdm(all_tokens) if t not in stopwords]
dataframe_nonstop = {}
dataframe_nonstop[opt] = FreqDist(eval(F"all_tokens_nonstop")).most_common(50)
freq_analysis_nonstop = pd.DataFrame(dataframe_nonstop)
# Out:
# 100%|██████████| 518289/518289 [00:02<00:00, 193433.69it/s]

# %%
freq_analysis_nonstop
# Out:
#               hafez
# 0        (., 16517)
# 1        (،, 16013)
# 2      (فیلم, 4199)
# 3         (:, 2114)
# 4         ((, 1757)
# 5         (), 1756)
# 6     (آن‌ها, 1679)
# 7     (سریال, 1627)
# 8         (؛, 1474)
# 9         («, 1286)
# 10        (», 1283)
# 11   (داستان, 1191)
# 12   (اپیزود, 1022)
# 13     (جیمی, 1011)
# 14      (قرار, 997)
# 15     (شخصیت, 924)
# 16       (کیم, 906)
# 17       (فصل, 891)
# 18         (؟, 880)
# 19  (به‌عنوان, 842)
# 20     (زندگی, 777)
# 21       (دست, 649)
# 22  (درباره‌ی, 641)
# 23   (استفاده, 632)
# 24      (اصلی, 621)
# 25       (کار, 615)
# 26     (مخاطب, 610)
# 27    (رینیرا, 590)
# 28       (The, 542)
# 29     (دنیای, 534)
# 30   (داستانی, 533)
# 31      (بازی, 532)
# 32      (نشان, 494)
# 33     (پایان, 485)
# 34        (سر, 477)
# 35       (بدل, 445)
# 36    (درواقع, 443)
# 37     (سکانس, 442)
# 38     (انجام, 440)
# 39      (ساول, 435)
# 40  (فیلم‌های, 431)
# 41       (مرگ, 428)
# 42       (شکل, 420)
# 43     (احساس, 420)
# 44       (نقش, 415)
# 45    (هاوارد, 405)
# 46      (تلاش, 403)
# 47      (قسمت, 386)
# 48   (انیمیشن, 378)
# 49     (تصمیم, 376)

# %%
stemmer = Stemmer()
lemmatizer = Lemmatizer()

def get_lemma_set(tok, opt=1):
    if opt ==1:
        return stemmer.stem(tok)
    if opt ==2:
        return lemmatizer.lemmatize(tok)
    return

# %%
all_tokens_nonstop_lemstem = [get_lemma_set(t, 1) for t in all_tokens_nonstop]
dataframe_nonstop_lemstem = {}
dataframe_nonstop_lemstem["all"] = FreqDist(eval(F"all_tokens_nonstop_lemstem")).most_common(50)
freq_analysis_nonstop_lemstem = pd.DataFrame(dataframe_nonstop_lemstem)   
freq_analysis_nonstop_lemstem
# Out:
#                all
# 0       (., 16517)
# 1       (،, 16013)
# 2      (فیل, 4210)
# 3        (:, 2114)
# 4        ((, 1757)
# 5        (), 1756)
# 6    (سریال, 1745)
# 7       (آن, 1717)
# 8        (؛, 1474)
# 9        («, 1286)
# 10       (», 1283)
# 11     (داس, 1193)
# 12       (ک, 1141)
# 13  (اپیزود, 1140)
# 14     (کار, 1053)
# 15     (جیم, 1011)
# 16    (قرار, 1005)
# 17      (شخص, 987)
# 18     (دنیا, 920)
# 19      (فصل, 912)
# 20     (فیلم, 887)
# 21        (؟, 880)
# 22   (به‌عنو, 842)
# 23    (شخصیت, 810)
# 24     (زندگ, 782)
# 25    (مخاطب, 775)
# 26       (پا, 717)
# 27   (داستان, 679)
# 28  (استفاده, 673)
# 29      (مرد, 670)
# 30   (درباره, 659)
# 31       (دس, 657)
# 32      (اصل, 656)
# 33    (احساس, 652)
# 34    (اتفاق, 649)
# 35        (ن, 643)
# 36    (سکانس, 616)
# 37     (صحنه, 597)
# 38   (رینیرا, 595)
# 39     (ایده, 592)
# 40       (سر, 585)
# 41      (شکل, 546)
# 42      (The, 542)
# 43      (باز, 536)
# 44     (واقع, 535)
# 45      (نما, 523)
# 46      (سال, 523)
# 47       (بد, 488)
# 48      (مرگ, 484)
# 49    (سینما, 482)

# %%
tagger = POSTagger(model=pos_tagger_model_address)

# %%
import copy
dataframe_nonstop_lemstem_advjj = {}
selected_verb = []
selected_adj = []
selected_noun = []
selected_adv = []
for x,y in FreqDist(eval(F"all_tokens_nonstop_lemstem")).most_common(1000):
    pos = tagger.tag([x])[0][1]
    if pos in ['N']:
        selected_noun.append((x,y))
    if pos in ['AJ']:
        selected_adj.append((x,y))
    if pos in ['V']:
        selected_verb.append((x,y))
    if pos in ['ADV']:
        selected_adv.append((x,y))
dataframe_nonstop_lemstem_advjj["noun"]= copy.deepcopy(selected_noun[0:25])
dataframe_nonstop_lemstem_advjj["verb"]= copy.deepcopy(selected_verb[0:25])
dataframe_nonstop_lemstem_advjj["adj"]= copy.deepcopy(selected_adj[0:25])
dataframe_nonstop_lemstem_advjj["adv"]= copy.deepcopy(selected_adv[0:25])
dataframe_nonstop_lemstem_advjj = pd.DataFrame(dataframe_nonstop_lemstem_advjj)

# %%
dataframe_nonstop_lemstem_advjj
# Out:
#               noun              verb              adj             adv
# 0      (فیل, 4210)   (می‌خواهد, 274)        (بد, 488)      (باز, 536)
# 1    (سریال, 1745)     (می‌زند, 264)       (روا, 381)    (واقعا, 257)
# 2      (داس, 1193)       (بدهد, 259)      (جذاب, 371)      (جلو, 227)
# 3        (ک, 1141)     (می‌برد, 218)      (موفق, 310)    (دقیقا, 196)
# 4   (اپیزود, 1140)    (نمی‌کند, 215)      (بزرگ, 301)     (اصلا, 161)
# 5      (کار, 1053)  (نمی‌تواند, 203)      (تازه, 268)  (احتمالا, 160)
# 6      (جیم, 1011)      (بگیرد, 191)     (مختلف, 260)     (هرگز, 152)
# 7     (قرار, 1005)     (می‌کشد, 181)    (ترسناک, 226)     (صرفا, 151)
# 8       (شخص, 987)   (می‌گذارد, 180)       (مهم, 223)   (آن‌قدر, 149)
# 9      (دنیا, 920)    (شده‌اند, 178)      (آشنا, 222)    (ابتدا, 145)
# 10      (فصل, 912)    (می‌افتد, 167)      (منجر, 217)    (انگار, 143)
# 11     (فیلم, 887)   (کرده‌اند, 164)     (مشغول, 213)   (تقریبا, 136)
# 12   (به‌عنو, 842)      (باشید, 161)     (مشابه, 202)     (هرچه, 132)
# 13    (شخصیت, 810)    (می‌آورد, 155)     (به‌جا, 190)  (بالاخره, 130)
# 14     (زندگ, 782)     (بتواند, 153)     (مقابل, 183)      (گاه, 125)
# 15    (مخاطب, 775)       (برسد, 150)      (ساده, 179)      (حال, 125)
# 16       (پا, 717)        (باش, 130)      (عمیق, 173)    (نسبتا, 115)
# 17   (داستان, 679)    (می‌داند, 125)  (دراماتیک, 166)    (ظاهرا, 104)
# 18  (استفاده, 673)   (می‌گیرند, 115)      (شبیه, 161)      (مثلا, 94)
# 19      (مرد, 670)    (نمی‌دهد, 107)      (جدید, 159)     (امروز, 92)
# 20       (دس, 657)     (می‌بیند, 97)     (کوتاه, 158)      (درست, 90)
# 21      (اصل, 656)     (می‌توان, 97)      (عجیب, 153)    (معمولا, 87)
# 22    (اتفاق, 649)        (برود, 93)     (تاریک, 150)       (زود, 87)
# 23        (ن, 643)        (بکشد, 91)     (درگیر, 149)     (پایین, 87)
# 24    (سکانس, 616)   (می‌اندازد, 91)      (سیاه, 145)  (بلافاصله, 82)

# %%
full_text = nltk.Text(all_tokens_nonstop_lemstem)
full_text.concordance("صحنه")
# Out:
# Displaying 25 of 25 matches:
# موضوع درباره برادر بزرگ‌تر جیس صادق : صحنه تمرین شمشیرزن آن ساحل ، جیس نق کریستو
# ز بنجامین واکر موقع هشدار الروند طراح صحنه محیط ساخ حلقه ابزار حاضر . دیالوگ‌نوی
# حدود ، نمونه قبلا اپیزود ش دیده_بود : صحنه لاریس زندان کشتن پدر برادر انتخاب ، ل
# اشا بریده زبان ، حین تحقیر آن ، انگار صحنه تحریک‌کننده . پا اپیزود ش لاریس واکن
# ل ، لطیف ، زیبا پیچیده ؛ نحوه قاب‌بند صحنه ظاهر معمول جزئی صدا محیط ، کل جمله نح
# افسردگ کال ؛ صدا آزارنده زیرمتن تک‌تک صحنه فیل حضور محسوس . آفتاب ، پرداخ مینیما
# خ پاول مسکال ؛ یک‌سو فضا ذهن واحد شخص صحنه خلق تضاد تلاش نما رفتار درس لحظه قرار
# یق . ولز شکل زیرکانه ، ازطریق میزانسن صحنه داخل اتاق هتل ، نما رفتن پدر ر نامعمو
# ن فضا امن سوف ساخته به‌تصویر می‌کشد . صحنه بازکردن پرزحم گچ دس ؛ کال وضع فیزیک س
# حوه به‌کارگیر ترانه « فشار » کوئین بو صحنه رقص پایان ) ، شخصیت اکثر دقایق فیل مق
#  فیل خلاصه مو گربه باز شخصیت فرار پنه صحنه اکشن دخ بلادستون تمرکز تلا مسابقه جای
# وب درجه سن بزرگسال دور مشکل ریختن خون صحنه نداشتند . مارول فیل Doctor Strange in
# سته_اس خشون خون فیل استفاده کنددرکنار صحنه اکشن نسبتا خشن ن مارول بخواهد پیاده ص
# ه اکشن نسبتا خشن ن مارول بخواهد پیاده صحنه برود محدودیت PG- ۱۳ دل بکند ، ظاهر گر
#  محکو ، موضوع درباره هلینا ، دخ صدق . صحنه آلیسن اتاق‌خواب اگ مشغول بازخواس اوس
# گو ، دیمون به‌عنو دس پادشاه نگه ندا . صحنه دیمون برادر وفادار می‌بود . ، دیمون ب
# نواده می‌نوشد ؛ درواقع ، آتو های‌تاور صحنه مشغول لبخند زدن تشویق رقص جیس هلینا د
#  . رفت‌و‌برگشت موقعیت بی‌کش خط زمان ، صحنه فلش‌بک فرط آشنا حوصله‌سر‌بر آب درآمده
#  اجرا معمول بارکر ( گا ظرف کمیک موجود صحنه هدر ) قرار ، فیل درگیر مخاطب دراماتیک
# ، پتانسیل مراتب شخصیت اصل انیمیشن خلق صحنه کمد داشته‌اند ز صحنه حضور ، عملکرد جذ
#  اصل انیمیشن خلق صحنه کمد داشته‌اند ز صحنه حضور ، عملکرد جذاب بامزه‌تر . شخص بچه
# س ده می‌توان اثر صرفا سرگر ارائه . پا صحنه پا نسبتا هوشمندانه انیمیشن DC League
# مثال درباره زده_شد مثال دیگر مربوط‌به صحنه کفشدوزک لیمو « واگن سکو » یک‌دیگر درگ
# یربرداری تمیز ، همراه‌با خشونت گرافیک صحنه درگیر‌کننده چیز دستاو ، به‌واسطه دیال
# یربرداری تمیز ، همراه‌با خشونت گرافیک صحنه درگیر‌کننده ، استفاده طراح گرافیک برج

# %%
review_list_word_tokenized[0]
# Out:
# ['فیلم',
#  'مخلوقات',
#  'خدا',
#  '،',
#  'درامی',
#  'باحوصله',
#  'و',
#  'آرام\u200cسوز',
#  'است',
#  'که',
#  'تلاش',
#  'می\u200cکند',
#  'سوژه\u200cای',
#  'آشنا',
#  'را',
#  'از',
#  'زاویه\u200cای',
#  'تازه',
#  'ببیند',
#  '.']

# %%
for sent in review_list_word_tokenized[0:10]:
    print(tagger.tag(sent[0]))
# Out:
# [('فیلم', 'Ne'), ('مخلوقات', 'Ne'), ('خدا', 'N'), ('،', 'PUNC'), ('درامی', 'N'), ('باحوصله', 'N'), ('و', 'CONJ'), ('آرام\u200cسوز', 'N'), ('است', 'V'), ('که', 'CONJ'), ('تلاش', 'N'), ('می\u200cکند', 'V'), ('سوژه\u200cای', 'N'), ('آشنا', 'AJ'), ('را', 'POSTP'), ('از', 'P'), ('زاویه\u200cای', 'N'), ('تازه', 'ADV'), ('ببیند', 'V'), ('.', 'PUNC')]
# [('در', 'P'), ('اپیزود', 'N'), ('دهم', 'NUM'), ('خاندان', 'Ne'), ('اژدها', 'N'), ('جنگ', 'Ne'), ('کلاغ\u200cها', 'N'), ('،', 'PUNC'), ('فرستاده\u200cها', 'N'), ('و', 'CONJ'), ('معاهدات', 'Ne'), ('ازدواج', 'N'), ('به', 'P'), ('پایان', 'N'), ('می\u200cرسد', 'V'), ('و', 'CONJ'), ('جنگ', 'Ne'), ('آتش', 'N'), ('و', 'CONJ'), ('خون', 'N'), ('با', 'P'), ('نهایت', 'Ne'), ('جدیت', 'N'), ('آغاز', 'N'), ('می\u200cشود', 'V'), ('.', 'PUNC')]
# [('این', 'DET'), ('فیلم', 'Ne'), ('کوچک', 'AJ'), ('،', 'PUNC'), ('ساده', 'AJ'), ('و', 'CONJ'), ('جمع\u200cوجور', 'AJ'), ('احتمالن', 'N'), ('یکی', 'NUM'), ('از', 'P'), ('بهترین', 'AJ'), ('فیلم\u200cهای', 'Ne'), ('سال', 'Ne'), ('۲۰۲۲', 'NUMe'), ('میلادی', 'AJ'), ('است', 'V'), ('.', 'PUNC')]
# [('جاستین', 'N'), ('رویلند', 'V'), ('،', 'PUNC'), ('خالق', 'Ne'), ('ریک', 'N'), ('و', 'CONJ'), ('مورتی', 'N'), ('،', 'PUNC'), ('با', 'P'), ('The', 'RES'), ('Paloni', 'RES'), ('Show', 'RES'), ('!', 'PUNC')]
# [('فیلم', 'Ne'), ('سگ\u200cهای', 'Ne'), ('پوشالی', 'AJe'), ('محصول', 'Ne'), ('۱۹۷۱', 'NUM'), ('،', 'PUNC'), ('ششمین', 'NUM'), ('فیلم', 'Ne'), ('سام', 'N'), ('پکین\u200cپای', 'Ne'), ('آمریکایی', 'AJ'), ('،', 'PUNC'), ('داستانی', 'N'), ('است', 'V'), ('از', 'P'), ('بروز', 'N'), ('و', 'CONJ'), ('فوران', 'Ne'), ('ناگهانی', 'AJe'), ('خشم', 'N'), ('در', 'P'), ('آدمی', 'N'), ('سربه\u200cزیر', 'AJ'), ('.', 'PUNC')]
# [('سریال', 'Ne'), ('She-Hulk', 'RES'), (':', 'PUNC'), ('Attorney', 'RES'), ('at', 'RES'), ('Law', 'RES'), ('با', 'P'), ('حضور', 'Ne'), ('افتخاری', 'AJe'), ('شخصیت\u200cهای', 'Ne'), ('مختلف', 'AJe'), ('مارول', 'N'), ('،', 'PUNC'), ('تلاش', 'N'), ('می\u200cکند', 'V'), ('تا', 'CONJ'), ('شخصیت', 'Ne'), ('شی', 'Ne'), ('هالک', 'N'), ('را', 'POSTP'), ('وارد', 'Pe'), ('دنیای', 'Ne'), ('سینمایی', 'AJ'), ('مارول', 'N'), ('کند', 'V'), ('.', 'PUNC'), ('سریال', 'Ne'), ('شی', 'Ne'), ('هالک', 'N'), ('جدیدترین', 'AJ'), ('سریال', 'Ne'), ('دنیای', 'Ne'), ('سینمایی', 'AJe'), ('مارول', 'N'), ('برای', 'Pe'), ('شبکه', 'Ne'), ('دیزنی', 'N'), ('پلاس', 'N'), ('است', 'V'), ('که', 'CONJ'), ('مدتی', 'N'), ('می\u200cشود', 'V'), ('پخش', 'Ne'), ('آن', 'PRO'), ('با', 'P'), ('انتشار', 'Ne'), ('قسمت', 'Ne'), ('نهم', 'NUM'), ('به', 'P'), ('پایان', 'N'), ('رسیده_است', 'V'), ('.', 'PUNC')]
# [('چند', 'DET'), ('تئوری', 'N'), ('درست', 'AJ'), ('از', 'P'), ('آب', 'N'), ('درآمدند', 'V'), ('،', 'PUNC'), ('برخی', 'DET'), ('از', 'P'), ('تصمیمات', 'Ne'), ('داستانی', 'AJ'), ('بحث\u200cبرانگیز', 'AJ'), ('را', 'POSTP'), ('به', 'P'), ('تماشا', 'N'), ('نشستیم', 'V'), ('،', 'PUNC'), ('تصویرسازی\u200cهای', 'Ne'), ('سریال', 'Ne'), ('چشم\u200cنواز', 'AJ'), ('باقی', 'N'), ('ماندند', 'V'), ('و', 'CONJ'), ('فصل', 'Ne'), ('اول', 'NUMe'), ('ارباب', 'Ne'), ('حلقه\u200cها', 'N'), (':', 'PUNC'), ('حلقه\u200cهای', 'Ne'), ('قدرت', 'N'), ('به', 'P'), ('پایان', 'N'), ('رسید', 'V'), ('.', 'PUNC'), ('در', 'P'), ('بسیاری', 'DET'), ('از', 'P'), ('مواقعی', 'N'), ('که', 'CONJ'), ('آثار', 'Ne'), ('سینمایی', 'AJ'), ('و', 'CONJ'), ('تلویزیونی', 'AJe'), ('پرمخاطب', 'AJ'), ('با', 'P'), ('یک', 'NUM'), ('تصمیم', 'Ne'), ('داستانی', 'AJe'), ('مهم', 'AJ'), ('وارد', 'Pe'), ('بخش', 'Ne'), ('بعدی', 'AJe'), ('داستان\u200cگویی', 'N'), ('خود', 'PRO'), ('می\u200cشوند', 'V'), ('،', 'PUNC'), ('ذهن', 'N'), ('تعداد', 'Ne'), ('زیادی', 'AJ'), ('از', 'P'), ('بینندگان', 'N'), ('به', 'P'), ('سمت', 'Ne'), ('بررسی', 'Ne'), ('مسیر', 'Ne'), ('طی\u200cشده', 'AJ'), ('تا', 'P'), ('آن', 'DET'), ('تصمیم', 'N'), ('می\u200cرود', 'V'), ('.', 'PUNC'), ('مسئله', 'N'), ('فقط', 'ADV'), ('درباره\u200cی', 'Pe'), ('این', 'PRO'), ('نیست', 'V'), ('که', 'CONJ'), ('آن', 'DET'), ('پیچش', 'N'), ('در', 'P'), ('روایت', 'Ne'), ('قصه', 'N'), ('چه\u200cقدر', 'ADV'), ('خوب', 'AJ'), ('یا', 'CONJ'), ('بد', 'AJ'), ('اجرا', 'N'), ('شد', 'V'), ('.', 'PUNC')]
# [('در', 'P'), ('اپیزود', 'Ne'), ('نهم', 'NUMe'), ('خاندان', 'Ne'), ('اژدها', 'N'), ('ملکه', 'Ne'), ('آلیسنت', 'N'), ('متوجه', 'AJ'), ('می\u200cشود', 'V'), ('که', 'CONJ'), ('تلاشش', 'N'), ('برای', 'Pe'), ('آزاد', 'AJ'), ('شدن', 'N'), ('از', 'P'), ('زیر', 'Ne'), ('سلطه\u200cی', 'Ne'), ('مردان', 'Ne'), ('زندگی\u200cاش', 'N'), ('در', 'P'), ('حقیقت', 'N'), ('چیزی', 'N'), ('بیش', 'AJ'), ('از', 'P'), ('ساختن', 'Ne'), ('پنجره\u200cای', 'N'), ('روی', 'Pe'), ('دیوار', 'N'), ('زندانش', 'N'), ('نیست', 'V'), ('.', 'PUNC')]
# [('فیلم', 'Ne'), ('جسد', 'Ne'), ('جسد', 'Ne'), ('جسد', 'N'), ('یا', 'CONJ'), ('Bodies', 'RES'), ('Bodies', 'RES'), ('Bodies', 'RES'), ('به', 'P'), ('کارگردانی', 'Ne'), ('هالینا', 'N'), ('رین', 'N'), ('،', 'PUNC'), ('یک', 'NUM'), ('کمدی', 'Ne'), ('ترسناک', 'AJ'), ('با', 'P'), ('یک', 'NUM'), ('طرح', 'Ne'), ('داستانی', 'AJe'), ('معمایی', 'AJ'), ('و', 'CONJ'), ('مجموعه\u200cای', 'N'), ('از', 'P'), ('شخصیت\u200cهای', 'Ne'), ('ناخوشایند', 'AJ'), ('است', 'V'), ('.', 'PUNC')]
# [('کریستین', 'N'), ('تافدروپ', 'N'), ('بازیگر', 'N'), ('و', 'CONJ'), ('کارگردان', 'Ne'), ('دانمارکی', 'AJ'), ('،', 'PUNC'), ('در', 'P'), ('سومین', 'NUM'), ('فیلم', 'Ne'), ('بلند', 'AJe'), ('داستانی\u200cاش', 'AJ'), ('،', 'PUNC'), ('از', 'P'), ('پلیدی', 'N'), ('نگو', 'V'), ('یا', 'CONJ'), ('Speak', 'RES'), ('No', 'RES'), ('Evil', 'RES'), ('،', 'PUNC'), ('آداب', 'Ne'), ('قراردادی', 'AJe'), ('بورژوازی', 'AJ'), ('را', 'POSTP'), ('با', 'P'), ('طنزی', 'N'), ('هولناک', 'AJ'), ('به', 'P'), ('نقد', 'N'), ('می\u200cکشاند', 'V'), ('.', 'PUNC')]
